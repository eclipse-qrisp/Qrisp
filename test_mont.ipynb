# %%
from qrisp import jaspify, QuantumFloat, modinv, jasp_fourier_adder, gidney_adder, measure, boolean_simulation, QuantumModulus, QuantumBool, control
from qrisp.alg_primitives.arithmetic.jasp_arithmetic.jasp_montgomery import qq_montgomery_multiply, compute_aux_radix_exponent, cq_montgomery_multiply, best_montgomery_shift, cq_montgomery_multiply_inplace 
import numpy as np

# %%
@boolean_simulation
def qq(a, b, n, N):
    qa = QuantumFloat(n)
    qa[:] = a
    qb = QuantumFloat(n)
    qb[:] = b
    m = compute_aux_radix_exponent(N, n)
    res = qq_montgomery_multiply(qa, qb, N, m, gidney_adder)
    return measure(qa), measure(qb), measure(res) 

for N in range(11, 50, 8):
    n = int(np.ceil(np.log2(N)))
    q = modinv(2**n, N)
    for a in range(1, 50, 3):
        for b in range(1, 50, 5):
            if a%N != 0 and b%N != 0:
                ar, br, rr = qq(a%N, b%N, n, N)
                assert ar == a%N
                assert br == b%N
                assert rr == (ar*br*q)%N

# %%
@boolean_simulation
def cq(a, b, n, N):
    qb = QuantumFloat(n)
    qb[:] = b
    shift = best_montgomery_shift(a, N)
    res = cq_montgomery_multiply(a, qb, N, shift, gidney_adder)
    return measure(qb), measure(res) 

for N in range(11, 50, 8):
    n = int(np.ceil(np.log2(N)))
    q = modinv(2**n, N)
    for a in range(4, 50, 3):
        for b in range(4, 50, 5):
            if a%N != 0 and b%N != 0:
                br, rr = cq(a%N, b%N, n, N)
                assert br == b%N
                assert rr == ((a%N)*br)%N

# %%
@boolean_simulation
def icq(a, b, n, N):
    qb = QuantumFloat(n)
    qb[:] = b
    shift = best_montgomery_shift(a, N)
    cq_montgomery_multiply_inplace(a, qb, N, shift, gidney_adder)
    return measure(qb)

for N in range(11, 50, 8):
    n = int(np.ceil(np.log2(N)))
    q = modinv(2**n, N)
    for a in range(4, 50, 3):
        for b in range(4, 50, 5):
            if a%N != 0 and b%N != 0 and np.gcd(a, N) == 1:
                br = icq(a%N, b%N, n, N)
                assert br == ((a%N)*(b%N))%N

# %%
@boolean_simulation
def cicq(a, b, n, N, c):
    qb = QuantumFloat(n)
    qb[:] = b
    shift = best_montgomery_shift(a, N)
    qc = QuantumBool()
    qc[:] = c
    with control(qc[0]):
        cq_montgomery_multiply_inplace(a, qb, N, shift, gidney_adder)
    return measure(qb)

for N in range(11, 50, 8):
    n = int(np.ceil(np.log2(N)))
    q = modinv(2**n, N)
    for a in range(4, 50, 3):
        for b in range(4, 50, 5):
            for c in [0, 1]:
                if a%N != 0 and b%N != 0 and np.gcd(a, N) == 1:
                    br = cicq(a%N, b%N, n, N, c)
                    assert br == (((a%N)**c)*(b%N))%N

# %%
import numpy as np
from qrisp import boolean_simulation, QuantumFloat, QuantumBool, modinv, gidney_adder, measure, control, BigInteger
from qrisp.alg_primitives.arithmetic.jasp_arithmetic.jasp_montgomery import cq_montgomery_multiply_inplace, best_montgomery_shift
@boolean_simulation
def bicicq(a, b, n, N, c):
    a = BigInteger.from_int(a, 3)
    N = BigInteger.from_int(N, 3)
    qb = QuantumFloat(n)
    qb[:] = b
    shift = best_montgomery_shift(a, N)
    qc = QuantumBool()
    qc[:] = c
    with control(qc[0]):
        cq_montgomery_multiply_inplace(a, qb, N, shift, gidney_adder)
    return measure(qb)

for N in range(11, 50, 8):
    n = int(np.ceil(np.log2(N)))
    for a in range(4, 50, 3):
        for b in range(4, 50, 5):
            for c in [0, 1]:
                if a%N != 0 and b%N != 0 and np.gcd(a, N) == 1:
                    br = bicicq(a%N, b%N, n, N, c)
                    assert br == (((a%N)**c)*(b%N))%N

# %%
from qrisp import QuantumFloat, modinv, gidney_adder, multi_measurement
from qrisp.alg_primitives.arithmetic.jasp_arithmetic.jasp_montgomery import qq_montgomery_multiply, compute_aux_radix_exponent

X = 29
y = 21
N = 31
n = 5

def test_qq_g():
    qx = QuantumFloat(n)
    qx[:] = X
    qy = QuantumFloat(n)
    qy[:] = y
    m = compute_aux_radix_exponent(N, n)
    res = qq_montgomery_multiply(qx, qy, N, m, gidney_adder)
    r = QuantumFloat(n)
    return multi_measurement([qx])

m = compute_aux_radix_exponent(N, n)

r = ((X*y*modinv(2**m, N))%N,)
test_qq_g()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 22
#      19 m = compute_aux_radix_exponent(N, n)
#      21 r = ((X*y*modinv(2**m, N))%N,)
# ---> 22 test_qq_g()
#
# Cell In[67], line 17, in test_qq_g()
#      15 res = qq_montgomery_multiply(qx, qy, N, m, gidney_adder)
#      16 r = QuantumFloat(n)
# ---> 17 return multi_measurement([qx])
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\misc\utility.py:789, in multi_measurement(qv_list, shots, backend)
#     786 for qa in recursive_qa_search(qv_list):
#     787     temp.extend(list(qa.flatten()))
# --> 789 compiled_qc = qompiler(
#     790     qv_list[0].qs, intended_measurements=sum([qv.reg for qv in temp], [])
#     791 )
#     792 # compiled_qc = qv_list[0].qs.copy()
#     793 # Add classical registers for the measurement results to be stored in
#     794 cl_reg_list = []
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\core\compilation.py:194, in qompiler(qs, workspace, disable_uncomputation, intended_measurements, cancel_qfts, compile_mcm, gate_speed, use_dirty_anc_for_mcx_recomp)
#     174 qc = cancel_inverses(qc)
#     176 # We now reorder the transpiled circuit to achieve a good (de)allocation order.
#     177 # Reordering is performed based on the DAG representation of Unqomp.
#     178 # The advantage of this representation is that
#    (...)    191 # previous order which might have been intentionally picked to optimize depth.
#     192 # In summary: Transpiling more aggressively leads to less qubits but more depth.
# --> 194 transpiled_qc = transpile(
#     195     qc, transpile_predicate=allocation_level_transpile_predicate
#     196 )
#     200 reordered_qc = optimize_allocations(transpiled_qc)
#     202 if cancel_qfts:
#     203     # Cancel adjacent QFT gates, which are inverse to each
#     204     # other. This can happen alot because of the heavy use of Fourier arithmetic
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\circuit\transpiler.py:70, in transpile(qc, transpilation_level, transpile_predicate, **kwargs)
#      65 else:
#      66     transpile_predicate_ = (
#      67         lambda i, op: i < transpilation_level and transpile_predicate(op)
#      68     )
# ---> 70 transpile_inner(qc, transpiled_qc, translation_dic, transpile_predicate_)
#      72 QuantumCircuit.fast_append = False
#      74 if not kwargs or not hasattr(qc, "to_qiskit"):
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\circuit\transpiler.py:119, in transpile_inner(transpilation_qc, target_qc, translation_dic, transpile_predicate, transpilation_level)
#     103         new_translation_dic = {
#     104             definition.qubits[j].identifier: translation_dic[
#     105                 instr.qubits[j].identifier
#     106             ]
#     107             for j in range(len(instr.qubits))
#     108         }
#     110         new_translation_dic.update(
#     111             {
#     112                 definition.clbits[j].identifier: translation_dic[
#    (...)    116             }
#     117         )
# --> 119         transpile_inner(
#     120             instr.op.definition,
#     121             target_qc,
#     122             new_translation_dic,
#     123             transpile_predicate,
#     124             transpilation_level + 1,
#     125         )
#     126         continue
#     128 if not isinstance(instr.op, Operation):
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\circuit\transpiler.py:136, in transpile_inner(transpilation_qc, target_qc, translation_dic, transpile_predicate, transpilation_level)
#     130 else:
#     131     op = instr.op
#     133 target_qc.data.append(
#     134     Instruction(
#     135         op,
# --> 136         [translation_dic[qb.identifier] for qb in instr.qubits],
#     137         [translation_dic[cb.identifier] for cb in instr.clbits],
#     138     )
#     139 )
#
# AttributeError: 'int' object has no attribute 'identifier'

# %%
@boolean_simulation
def qq(a, b, n, N):
    qa = QuantumModulus(13)
    #qa.m = 4
    #qa[:] = 3
    qb = QuantumModulus(13)
    #qb.m = 4
    #qb[:] = 3
    #res = qa * qb
    return measure(qa), measure(qb)#, measure(res) 

for N in range(11, 50, 8):
    n = int(np.ceil(np.log2(N)))
    q = modinv(2**n, N)
    for a in range(1, 50, 3):
        for b in range(1, 50, 5):
            if a%N != 0 and b%N != 0:
                qq(a%N, b%N, n, N)
                continue
                ar, br, rr = qq(a%N, b%N, n, N)
                assert ar == a%N
                assert br == b%N
                assert rr == (ar*br*q)%N
# Out:
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\traitlets\config\application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\tornado\platform\asyncio.py:205, in start()
#     204 def start(self) -> None:
# --> 205     self.asyncio_loop.run_forever()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:645, in run_forever()
#     644 while True:
# --> 645     self._run_once()
#     646     if self._stopping:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1999, in _run_once()
#    1998     else:
# -> 1999         handle._run()
#    2000 handle = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py:88, in _run()
#      87 try:
# ---> 88     self._context.run(self._callback, *self._args)
#      89 except (SystemExit, KeyboardInterrupt):
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\kernelbase.py:545, in dispatch_queue()
#     544 try:
# --> 545     await self.process_one()
#     546 except Exception:
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\kernelbase.py:534, in process_one()
#     533         return
# --> 534 await dispatch(*args)
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\kernelbase.py:437, in dispatch_shell()
#     436     if inspect.isawaitable(result):
# --> 437         await result
#     438 except Exception:
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\ipkernel.py:362, in execute_request()
#     361 self._associate_new_top_level_threads_with(parent_header)
# --> 362 await super().execute_request(stream, ident, parent)
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\kernelbase.py:778, in execute_request()
#     777 if inspect.isawaitable(reply_content):
# --> 778     reply_content = await reply_content
#     780 # Flush output before sending the reply.
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\ipkernel.py:449, in do_execute()
#     448 if accepts_params["cell_id"]:
# --> 449     res = shell.run_cell(
#     450         code,
#     451         store_history=store_history,
#     452         silent=silent,
#     453         cell_id=cell_id,
#     454     )
#     455 else:
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\ipykernel\zmqshell.py:549, in run_cell()
#     548 self._last_traceback = None
# --> 549 return super().run_cell(*args, **kwargs)
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3098, in run_cell()
#    3097 try:
# -> 3098     result = self._run_cell(
#    3099         raw_cell, store_history, silent, shell_futures, cell_id
#    3100     )
#    3101 finally:
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3153, in _run_cell()
#    3152 try:
# -> 3153     result = runner(coro)
#    3154 except BaseException as e:
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3362, in run_cell_async()
#    3359 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3362 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3363        interactivity=interactivity, compiler=compiler, result=result)
#    3365 self.last_execution_succeeded = not has_raised
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3607, in run_ast_nodes()
#    3606     asy = compare(code)
# -> 3607 if await self.run_code(code, result, async_=asy):
#    3608     return True
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3667, in run_code()
#    3666     else:
# -> 3667         exec(code_obj, self.user_global_ns, self.user_ns)
#    3668 finally:
#    3669     # Reset our crash handler in place
#
# Cell In[3], line 15
#      14 if a%N != 0 and b%N != 0:
# ---> 15     br, rr = cq(a%N, b%N, n, N)
#      16     assert br == b%N
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\evaluation_tools\boolean_simulation.py:173, in return_function()
#     170 @jit
#     171 def return_function(*args):
# --> 173     jaspr = make_jaspr(func, garbage_collection="manual")(*args)
#     175     for var in jaspr.outvars:
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\jasp_expression\centerclass.py:1281, in jaspr_creator()
#    1280 ammended_kwargs[10*"~"] = AbstractQuantumCircuit()
# -> 1281 closed_jaxpr = make_jaxpr(ammended_function, **jax_kwargs)(
#    1282     *args, **ammended_kwargs
#    1283 )
#    1285 # Collect the environments
#    1286 # This means that the quantum environments no longer appear as
#    1287 # enter/exit primitives but as primitive that "call" a certain Jaspr.
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\jasp_expression\centerclass.py:1266, in ammended_function()
#    1265 try:
# -> 1266     res = fun(*args, **kwargs)
#    1267 except Exception as e:
#
# Cell In[3], line 6, in cq()
#       5 shift = best_montgomery_shift(a, N)
# ----> 6 res = cq_montgomery_multiply(a, qb, N, shift, gidney_adder)
#       7 return measure(qb), measure(res)
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\alg_primitives\arithmetic\jasp_arithmetic\jasp_montgomery.py:122, in cq_montgomery_multiply()
#     121 if not x_is_montgomery:
# --> 122     X = montgomery_encoder(X, R, N)
#     123 N1 = modinv(N, R << 1)
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\alg_primitives\arithmetic\jasp_arithmetic\jasp_mod_tools.py:13, in montgomery_encoder()
#      12 def montgomery_encoder(y, R, N):
# ---> 13     return ((y % N) * (R % N)) % N
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\jax\_src\numpy\array_methods.py:1060, in op()
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\jax\_src\numpy\array_methods.py:579, in deferring_binary_op()
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\jax\_src\numpy\ufuncs.py:3118, in mod()
#    3117 """Alias of :func:`jax.numpy.remainder`"""
# -> 3118 return remainder(x1, x2)
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\jax\_src\numpy\ufuncs.py:3106, in remainder()
#    3105   x2 = _where(x2 == 0, lax._ones(x2), x2)
# -> 3106 trunc_mod = lax.rem(x1, x2)
#    3107 trunc_mod_not_zero = lax.ne(trunc_mod, zero)
#
# JaxStackTraceBeforeTransformation: TypeError: lax.rem requires arguments to have the same dtypes, got float64, int64.
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 18
#      16 for b in range(1, 50, 5):
#      17     if a%N != 0 and b%N != 0:
# ---> 18         qq(a%N, b%N, n, N)
#      19         continue
#      20         ar, br, rr = qq(a%N, b%N, n, N)
#
#     [... skipping hidden 14 frame]
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\evaluation_tools\boolean_simulation.py:179, in boolean_simulation.<locals>.return_function(*args)
#     176     if isinstance(var.aval, (AbstractQubitArray, AbstractQubit)):
#     177         raise Exception("Tried to perform boolean simulation of a function returning a quantum value (please measure before returning)")
# --> 179 cl_func_jaxpr = jaspr_to_cl_func_jaxpr(
#     180     jaspr.flatten_environments(), bit_array_padding
#     181 )
#     183 # Get the abstract value of the bit array representing the bit state
#     184 aval = cl_func_jaxpr.jaxpr.invars[-3].aval
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\interpreter_tools\interpreters\cl_func_interpreter.py:493, in jaspr_to_cl_func_jaxpr(jaspr, bit_array_padding)
#     490     else:
#     491         args.append(invar.aval)
# --> 493 return make_jaxpr(eval_jaxpr(jaspr, eqn_evaluator=cl_func_eqn_evaluator))(
#     494     *args
#     495 )
#
#     [... skipping hidden 15 frame]
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\interpreter_tools\abstract_interpreter.py:81, in eval_jaxpr.<locals>.jaxpr_evaluator(*args)
#      78     raise Exception("Tried to evaluate jaxpr with insufficient arguments")
#      80 context_dic = ContextDict({temp_var_list[i]: args[i] for i in range(len(args))})
# ---> 81 eval_jaxpr_with_context_dic(jaxpr, context_dic, eqn_evaluator)
#      83 if return_context_dic:
#      84     outvals = [context_dic]
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\interpreter_tools\abstract_interpreter.py:126, in eval_jaxpr_with_context_dic(jaxpr, context_dic, eqn_evaluator)
#     121 def eval_jaxpr_with_context_dic(jaxpr, context_dic, eqn_evaluator=exec_eqn):
#     122
#     123     # Iterate through the equations
#     124     for eqn in jaxpr.eqns:
#     125         # Evaluate the primitive
# --> 126         default_eval = eqn_evaluator(eqn, context_dic)
#     128         if default_eval:
#     129             if (
#     130                 eqn.primitive.name in ["while", "cond", "scan"]
#     131                 and not check_for_tracing_mode()
#     132             ):
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\interpreter_tools\interpreters\cl_func_interpreter.py:81, in cl_func_eqn_evaluator(eqn, context_dic)
#      79     return process_cond(eqn, context_dic)  #
#      80 elif eqn.primitive.name == "pjit":
# ---> 81     process_pjit(eqn, context_dic)
#      82 else:
#      83     return True
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\interpreter_tools\interpreters\cl_func_interpreter.py:404, in process_pjit(eqn, context_dic)
#     401     traced_fun = get_traced_fun(jaxpr, bit_array_padding)
#     403     flattened_invalues = flatten_signature(invalues, eqn.invars)
# --> 404     outvalues = traced_fun(*flattened_invalues)
#     405     unflattened_outvalues = unflatten_signature(outvalues, eqn.outvars)
#     407 insert_outvalues(eqn, context_dic, unflattened_outvalues)
#
#     [... skipping hidden 14 frame]
#
# File C:\Projects\UnaryIteration\Qrisp\src\qrisp\jasp\interpreter_tools\interpreters\cl_func_interpreter.py:368, in get_traced_fun.<locals>.jitted_fun(*args)
#     366 @jit
#     367 def jitted_fun(*args):
# --> 368     return eval_jaxpr(cl_func_jaxpr.jaxpr, cl_func_jaxpr.consts, *args)
#
#     [... skipping hidden 10 frame]
#
# File c:\Projects\UnaryIteration\Qrisp\.venv\Lib\site-packages\jax\_src\lax\lax.py:8702, in check_same_dtypes(name, *avals)
#    8700   equiv = _JNP_FUNCTION_EQUIVALENTS[name]
#    8701   msg += f" (Tip: jnp.{equiv} is a similar function that does automatic type promotion on inputs)."
# -> 8702 raise TypeError(msg.format(name, ", ".join(str(a.dtype) for a in avals)))
#
# TypeError: lax.rem requires arguments to have the same dtypes, got float64, int64.
