# %% [markdown]
# # Block encodings as programming abstraction and Quantum Linear Algebra using the BlockEncoding class
#
# Motivation, goal, ...
#
# ## Basic theoretical concepts.
#
# ### Block encoding 101
#
# ### Unification of Quantum Algorithms/QSP/GQSP/GQET
#
# ## BlockEncoding class showcase
#
# motivation
#
# ### how to construct a BE object (quantum numpy)
#
# #### ``from_operator``
# Explain that it block‑encodes the Hermitian part of the operator and internally uses a Pauli decomposition.​

# %%
###### EXAMPLE

# %% [markdown]
# #### ``.from_array``
# Square matrix, size a power of two, supports `ndarray`, `csrarray`, `csrmatrix`.​

# %%
### EXAMPLE

# %% [markdown]
# #### ``.from_LCU``
# Introduce `BlockEncoding.from_lcu(coeffs, unitaries)` and the PREP–SEL–PREP† construction.​
#
# Explain padding of coefficients, normalization α=∑i∣αi∣α=∑i∣αi∣, sign handling via additional phase flips, and how `qswitch` is used inside. ​

# %%
### EXAMPLE

### EXAMPLE: Laplacian example already in the doc (1D discrete Laplace), show how to write `unitaries = [I, V, V_dag]` and `coeffs`, then `BE = BlockEncoding.from_lcu(coeffs, unitaries)`.​

# %% [markdown]
# #### Algebra of BlockEncodings: +, -, *, @, .kron, .neg
#
# Goal: Show how to combine block encodings using operator overloading.
#
# Subsections, each with short explanation and one standalone example:
#
# ##### adition ``__add__``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ##### subtraction ``__sub__``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ##### scalar multiplication ``__mul__``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ##### matrix multiplication ``__matmul__``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ##### kronecker product ``__.kron__``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ##### negation ``__neg__``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# #### Chebyshev polynomial using ``.chebyshev``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# #### Inverse using ``.inv``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# #### Polynomial transformations using ``.poly``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# #### Hamiltnian simulation using ``.sim``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ### Resource estimation using ``.resources``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ### Applying a BlockEncoding (quantum LAPACK)
#
# Goal: Demonstrate how to actually use a `BlockEncoding` to act on states.
#
# #### ``.apply``
# EXPLAIN
#
# EXPLAIN NISQ-FRIENDLY POST-SELECTION APPROACH

# %%
### EXAMPLE

# %% [markdown]
# #### ``.apply_rus``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ### Further examples

# %%
### EXAMPLE

# %%
### EXAMPLE

# %%
### EXAMPLE

# %% [markdown]
# ### Wrap-up
