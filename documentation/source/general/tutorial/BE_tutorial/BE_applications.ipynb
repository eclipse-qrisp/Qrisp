# %% [markdown]
# # Part II: Advanced Applications and executing Algorithms
#
# With getting familiar with the basic functionalities of the BlockEncoding class in the previous tutorial, we now shift up a gear and tackle some of the recent, relevant open questions. We explore and showcase the methods that allow you to use the BlockEncodings for:
#
# - Qubitization: Leverage .qubitization and .chebyshev to walk through Krylov subspaces with optimal query complexity.
#
# - Solving Linear Systems: Perform matrix inversion on the block encoding of your construction with ``.inv``.
#
# - Polynomial Transformations: Apply an arbitrary polynomial transformation of a matrix in either the polynomial or Chebyshev basis using ``.poly``. This is also useful to perform GQSP filtering, which is a topic of a separate tutorial.
#
# - Hamiltonian simulation: Want to perform a Hamiltonian simulation with your block encoding? Sure, by all means... ``.sim`` can help with that.
# ### Resource estimation using ``.resources``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# ### Applying a BlockEncoding (quantum LAPACK)
#
# Goal: Demonstrate how to actually use a `BlockEncoding` to act on states.
#
# #### ``.apply``
# EXPLAIN
#
# EXPLAIN NISQ-FRIENDLY POST-SELECTION APPROACH

# %%
### EXAMPLE

# %% [markdown]
# #### ``.apply_rus``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# #### Inverse using ``.inv``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# #### Polynomial transformations using ``.poly``
#
# EXPLAIN

# %%
### EXAMPLE

# %% [markdown]
# #### Hamiltnian simulation using ``.sim``
#
# EXPLAIN

# %%
### EXAMPLE
